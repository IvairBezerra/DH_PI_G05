# %% [markdown]
# ## Import libs

# %%
import requests as req
import numpy as np
import pandas as pd
import json

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Connecting to isbndb API

# %%
#home page: https://isbndb.com/
#doc: https://isbndb.com/apidocs/v2

h = {'Authorization': '48848_0d5c41033956592917fb92bcd923b67a'}

# %% [markdown]
# ## Import Kaggle data books

# %%
dfBooks = pd.read_csv('Books.csv',low_memory=False)
dfUsers = pd.read_csv('Ratings.csv',low_memory=False)
dfRating = pd.read_csv('Users.csv',low_memory=False)

dfBooks.head(1)
# Out:
#          ISBN           Book-Title         Book-Author Year-Of-Publication  \
# 0  0195153448  Classical Mythology  Mark P. O. Morford                2002
#
#                  Publisher                                        Image-URL-S  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...

# %% [markdown]
# ## Collecting data

# %%
#list size of search
group_size = 100

#Slicing ISBN
dfList = dfBooks.iloc[0:group_size, 0:1].sort_values(by = 'ISBN')

#List of ISBN
dfList = dfList['ISBN'].values.tolist()

#batch search
df = pd.DataFrame()
for i in dfList:
    resp = req.get(f"https://api2.isbndb.com/book/{i}", headers=h).json()
    x = pd.DataFrame.from_dict(resp, 'index')
    df = df.append(x,ignore_index=True)

#Export
df.to_csv("Lote1.csv")

df.head()
# Out:
#                   publisher  \
# 0      HarperFlamingoCanada
# 1  HarperCollins Publishers
# 2             HarperCollins
# 3   Harper & Row Publishers
# 4             HarperCollins
#
#                                             synopsis language  \
# 0  Giller Prize Winner 2001. Richard B. Wright. A...       en
# 1  When A Six-year-old Child Named Turtle Is The ...       en
# 2  Standing Firm Leaves No Doubt That Dan Quayle ...       en
# 3                                                NaN       en
# 4  <p>this Sometimes Funny, Often Sad, But Comple...       en
#
#                                                image  \
# 0  https://images.isbndb.com/covers/50/12/9780002...
# 1  https://images.isbndb.com/covers/80/18/9780060...
# 2  https://images.isbndb.com/covers/75/84/9780060...
# 3  https://images.isbndb.com/covers/40/66/9780060...
# 4  https://images.isbndb.com/covers/03/63/9780060...
#
#                                           title_long  \
# 0                              Clara Callan: A novel
# 1                                     Pigs in Heaven
# 2                                      Standing Firm
# 3  Love, Medicine & Miracles by Bernie S. Siegel ...
# 4  My First Cousin Once Removed: Money, Madness, ...
#
#                       edition  \
# 0                         1st
# 1               First Edition
# 2                           1
# 3  1rst prennial Library Edit
# 4               First Edition
#
#                                           dimensions  pages date_published  \
# 0  Height: 11.11 Inches, Length: 6.11 Inches, Wei...  414.0           2001
# 1                                   Weight: 1 Pounds  288.0           1993
# 2                                Weight: 1.75 Pounds  402.0           1994
# 3                                 Weight: 0.8 Pounds  243.0           1986
# 4  Height: 8 Inches, Length: 5.3125 Inches, Weigh...  260.0           1999
#
#                                             subjects                  authors  \
# 0  [Women Teachers, Young Women, Actresses, Sisters]  [Wright, Richard Bruce]
# 1                                                NaN    [Kingsolver, Barbara]
# 2                                                NaN            [Quayle, Dan]
# 3                                                NaN      [Siegel, Bernie S.]
# 4                                                NaN    [Stuart, Sarah Payne]
#
#                                                title         isbn13   msrp  \
# 0                              Clara Callan: A novel  9780002005012   0.00
# 1                                     Pigs in Heaven  9780060168018     23
# 2                                      Standing Firm  9780060177584   1.99
# 3  Love, Medicine & Miracles by Bernie S. Siegel ...  9780060914066   0.00
# 4  My First Cousin Once Removed: Money, Madness, ...  9780060930363  13.95
#
#      binding        isbn      isbn10 other_isbns related
# 0  Hardcover  0002005018  0002005018         NaN     NaN
# 1  Hardcover  0060168013  0060168013         NaN     NaN
# 2  Hardcover  0060177586  0060177586         NaN     NaN
# 3  Paperback  0060914068  0060914068         NaN     NaN
# 4  Paperback  0060930365  0060930365         NaN     NaN
